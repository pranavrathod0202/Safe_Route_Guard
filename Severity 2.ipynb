# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# %%
df=pd.read_csv("Severity Two Base Data.csv")
df
# Out:
#      Accident_Index  Location_Easting_OSGR   Location_Northing_OSGR  \
# 0      2.020000e+12                  461323                  452491
# 1      2.020000e+12                  462317                  446855
# 2      2.020000e+12                  464904                  456805
# 3      2.010000e+12                  465130                  451620
# 4      2.020000e+12                  456284                  453322
# ..              ...                     ...                     ...
# 851    2.010000e+12                  453620                  451310
# 852    2.010000e+12                  461950                  452040
# 853    2.010000e+12                  458840                  449920
# 854    2.010000e+12                  459280                  453030
# 855    2.010000e+12                  458630                  449510
#
#      Longitude   Latitude  Police_Force  Accident_Severity  \
# 0    -1.066777  53.964890            12                  2
# 1    -1.052775  53.914123            12                  2
# 2    -1.011285  54.003220            12                  2
# 3    -1.008917  53.956579            12                  2
# 4    -1.143421  53.972929            12                  2
# ..         ...        ...           ...                ...
# 851  -1.184360  53.955111            12                  2
# 852  -1.057287  53.960743            12                  2
# 853  -1.105089  53.942053            12                  2
# 854  -1.097784  53.969952            12                  2
# 855  -1.108367  53.938393            12                  2
#
#      Number_of_Vehicles  Number_of_Casualties        Date  ...  \
# 0                     1                     1  13/12/2018  ...
# 1                     4                     2       43385  ...
# 2                     2                     1       43445  ...
# 3                     2                     1       39904  ...
# 4                     1                     2  25/07/2018  ...
# ..                  ...                   ...         ...  ...
# 851                   2                     1       38362  ...
# 852                   2                     1  23/09/2005  ...
# 853                   2                     2  19/09/2005  ...
# 854                   1                     1  15/09/2005  ...
# 855                   2                     1  13/09/2005  ...
#
#      Pedestrian_Crossing-Human_Control  \
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0
# ..                                 ...
# 851                                  0
# 852                                  0
# 853                                  0
# 854                                  0
# 855                                  0
#
#      Pedestrian_Crossing-Physical_Facilities  Light_Conditions  \
# 0                                          0                 1
# 1                                          0                 1
# 2                                          0                 6
# 3                                          0                 4
# 4                                          0                 1
# ..                                       ...               ...
# 851                                        0                 1
# 852                                        0                 4
# 853                                        0                 1
# 854                                        0                 1
# 855                                        0                 1
#
#     Weather_Conditions  Road_Surface_Conditions  Special_Conditions_at_Site  \
# 0                    1                        1                           0
# 1                    1                        1                           0
# 2                    2                        2                           0
# 3                    1                        2                           0
# 4                    1                        1                           0
# ..                 ...                      ...                         ...
# 851                  1                        1                           0
# 852                  1                        1                           0
# 853                  1                        1                           0
# 854                  1                        2                           0
# 855                  1                        1                           0
#
#      Carriageway_Hazards  Urban_or_Rural_Area  \
# 0                      0                    1
# 1                      0                    2
# 2                      0                    2
# 3                      0                    2
# 4                      0                    2
# ..                   ...                  ...
# 851                    0                    2
# 852                    0                    1
# 853                    0                    1
# 854                    0                    1
# 855                    0                    1
#
#      Did_Police_Officer_Attend_Scene_of_Accident  LSOA_of_Accident_Location
# 0                                              1                  E01013380
# 1                                              1                  E01013450
# 2                                              1                  E01013437
# 3                                              1                  E01013351
# 4                                              1                  E01013422
# ..                                           ...                        ...
# 851                                            1                  E01013421
# 852                                            1                  E01013384
# 853                                            1                  E01013358
# 854                                            1                  E01013346
# 855                                            1                  E01013357
#
# [856 rows x 32 columns]

# %%
group1 = df[(df['Number_of_Casualties'] <= 1) & (df['Number_of_Casualties'] <3 )]
group2 = df[(df['Number_of_Casualties'] >= 3)]

# %%
group1
# Out:
#      Accident_Index  Location_Easting_OSGR   Location_Northing_OSGR  \
# 0      2.020000e+12                  461323                  452491
# 2      2.020000e+12                  464904                  456805
# 3      2.010000e+12                  465130                  451620
# 6      2.020000e+12                  454662                  447085
# 7      2.020000e+12                  466264                  457905
# ..              ...                     ...                     ...
# 847    2.010000e+12                  459530                  458420
# 851    2.010000e+12                  453620                  451310
# 852    2.010000e+12                  461950                  452040
# 854    2.010000e+12                  459280                  453030
# 855    2.010000e+12                  458630                  449510
#
#      Longitude   Latitude  Police_Force  Accident_Severity  \
# 0    -1.066777  53.964890            12                  2
# 2    -1.011285  54.003220            12                  2
# 3    -1.008917  53.956579            12                  2
# 6    -1.169259  53.917052            12                  2
# 7    -0.990301  54.012932            12                  2
# ..         ...        ...           ...                ...
# 847  -1.092921  54.018362            12                  2
# 851  -1.184360  53.955111            12                  2
# 852  -1.057287  53.960743            12                  2
# 854  -1.097784  53.969952            12                  2
# 855  -1.108367  53.938393            12                  2
#
#      Number_of_Vehicles  Number_of_Casualties        Date  ...  \
# 0                     1                     1  13/12/2018  ...
# 2                     2                     1       43445  ...
# 3                     2                     1       39904  ...
# 6                     2                     1  14/12/2018  ...
# 7                     2                     1  21/12/2018  ...
# ..                  ...                   ...         ...  ...
# 847                   1                     1  23/10/2005  ...
# 851                   2                     1       38362  ...
# 852                   2                     1  23/09/2005  ...
# 854                   1                     1  15/09/2005  ...
# 855                   2                     1  13/09/2005  ...
#
#      Pedestrian_Crossing-Human_Control  \
# 0                                    0
# 2                                    0
# 3                                    0
# 6                                    0
# 7                                    0
# ..                                 ...
# 847                                  0
# 851                                  0
# 852                                  0
# 854                                  0
# 855                                  0
#
#      Pedestrian_Crossing-Physical_Facilities  Light_Conditions  \
# 0                                          0                 1
# 2                                          0                 6
# 3                                          0                 4
# 6                                          0                 6
# 7                                          0                 1
# ..                                       ...               ...
# 847                                        0                 4
# 851                                        0                 1
# 852                                        0                 4
# 854                                        0                 1
# 855                                        0                 1
#
#     Weather_Conditions  Road_Surface_Conditions  Special_Conditions_at_Site  \
# 0                    1                        1                           0
# 2                    2                        2                           0
# 3                    1                        2                           0
# 6                    1                        2                           0
# 7                    2                        2                           0
# ..                 ...                      ...                         ...
# 847                  9                        2                           0
# 851                  1                        1                           0
# 852                  1                        1                           0
# 854                  1                        2                           0
# 855                  1                        1                           0
#
#      Carriageway_Hazards  Urban_or_Rural_Area  \
# 0                      0                    1
# 2                      0                    2
# 3                      0                    2
# 6                      0                    2
# 7                      0                    2
# ..                   ...                  ...
# 847                    7                    1
# 851                    0                    2
# 852                    0                    1
# 854                    0                    1
# 855                    0                    1
#
#      Did_Police_Officer_Attend_Scene_of_Accident  LSOA_of_Accident_Location
# 0                                              1                  E01013380
# 2                                              1                  E01013437
# 3                                              1                  E01013351
# 6                                              1                  E01013421
# 7                                              1                  E01013437
# ..                                           ...                        ...
# 847                                            1                  E01013377
# 851                                            1                  E01013421
# 852                                            1                  E01013384
# 854                                            1                  E01013346
# 855                                            1                  E01013357
#
# [622 rows x 32 columns]

# %%
group2
# Out:
#      Accident_Index  Location_Easting_OSGR   Location_Northing_OSGR  \
# 36     2.020000e+12                  464102                  455299
# 42     2.010000e+12                  461590                  453920
# 48     2.020000e+12                  462717                  444728
# 70     2.020000e+12                  465903                  456355
# 77     2.020000e+12                  458596                  454946
# ..              ...                     ...                     ...
# 816    2.020000e+12                  465597                  457387
# 828    2.020000e+12                  458218                  447960
# 843    2.010000e+12                  456030                  450570
# 848    2.010000e+12                  462890                  455590
# 850    2.010000e+12                  456170                  447130
#
#      Longitude   Latitude  Police_Force  Accident_Severity  \
# 36   -1.023836  53.989787            12                  2
# 42   -1.062394  53.977681            12                  2
# 48   -1.047121  53.894961            12                  2
# 70   -0.996144  53.999050            12                  2
# 77   -1.107867  53.987267            12                  2
# ..         ...        ...           ...                ...
# 816  -1.000580  54.008345            12                  2
# 828  -1.114953  53.924511            12                  2
# 843  -1.147774  53.948206            12                  2
# 848  -1.042231  53.992532            12                  2
# 850  -1.146272  53.917276            12                  2
#
#      Number_of_Vehicles  Number_of_Casualties        Date  ...  \
# 36                    2                     4       43286  ...
# 42                    2                     3  31/01/2009  ...
# 48                    3                     4  18/02/2018  ...
# 70                    2                     4       43049  ...
# 77                    1                     4       42803  ...
# ..                  ...                   ...         ...  ...
# 816                   2                     3       42159  ...
# 828                   6                     4  22/01/2015  ...
# 843                   2                     3       38575  ...
# 848                   2                     3       38666  ...
# 850                   2                     3       38635  ...
#
#      Pedestrian_Crossing-Human_Control  \
# 36                                   0
# 42                                   0
# 48                                   0
# 70                                   0
# 77                                   0
# ..                                 ...
# 816                                  0
# 828                                  0
# 843                                  0
# 848                                  0
# 850                                  0
#
#      Pedestrian_Crossing-Physical_Facilities  Light_Conditions  \
# 36                                         0                 1
# 42                                         0                 4
# 48                                         0                 1
# 70                                         0                 4
# 77                                         0                 4
# ..                                       ...               ...
# 816                                        0                 1
# 828                                        0                 6
# 843                                        0                 6
# 848                                        0                 1
# 850                                        0                 1
#
#     Weather_Conditions  Road_Surface_Conditions  Special_Conditions_at_Site  \
# 36                   1                        1                           0
# 42                   1                        2                           0
# 48                   1                        2                           0
# 70                   1                        1                           0
# 77                   1                        1                           0
# ..                 ...                      ...                         ...
# 816                  1                        1                           0
# 828                  1                        2                           0
# 843                  2                        2                           0
# 848                  1                        1                           0
# 850                  1                        1                           0
#
#      Carriageway_Hazards  Urban_or_Rural_Area  \
# 36                     0                    2
# 42                     0                    1
# 48                     0                    2
# 70                     0                    2
# 77                     0                    1
# ..                   ...                  ...
# 816                    0                    2
# 828                    0                    2
# 843                    0                    2
# 848                    0                    2
# 850                    0                    2
#
#      Did_Police_Officer_Attend_Scene_of_Accident  LSOA_of_Accident_Location
# 36                                             1                  E01013437
# 42                                             1                  E01013385
# 48                                             1                  E01013450
# 70                                             1                  E01013437
# 77                                             1                  E01013429
# ..                                           ...                        ...
# 816                                            1                  E01013437
# 828                                            1                  E01013340
# 843                                            1                  E01013421
# 848                                            1                  E01013409
# 850                                            1                  E01013424
#
# [85 rows x 32 columns]

# %%
import matplotlib.pyplot as plt
# Create a new column 'Accident Group' based on the number of accidents
df['No.of Vehicles Group'] = pd.cut(df['Number_of_Vehicles'], bins=[0, 5, 10, 100], labels=['1-2', '2-3', '>3'])

# Group the DataFrame by the 'Accident Group' column and count the number of locations for each group
grouped_df = df.groupby('No.of Vehicles Group')['Number_of_Casualties'].nunique()

# Print the grouped DataFrame
print(grouped_df)
# Group the DataFrame by the 'Accident Group' column and count the number of locations for each group
grouped_df = df.groupby('Number_of_Vehicles')['Number_of_Casualties'].nunique().reset_index(name='counts')

# Plot the bar chart
plt.bar(grouped_df['Number_of_Vehicles'], grouped_df['counts'])
plt.xlabel('Number_of_Vehicles')
plt.ylabel('Number_of_Casualtiess')
plt.title('Number of Vehicles and Casualty')
plt.show()
# Out:
# No.of Vehicles Group
# 1-2    8
# 2-3    1
# >3     0
# Name: Number_of_Casualties, dtype: int64

# %%
import matplotlib.pyplot as plt


grouped_df = df.groupby('Number_of_Vehicles')['Number_of_Casualties'].mean().reset_index()

# Plot the line graph
plt.plot(grouped_df['Number_of_Vehicles'], grouped_df['Number_of_Casualties'])
plt.xlabel('Number of Accidents')
plt.ylabel('Number of Fatalities')
plt.title('Number of Fatalities by Number of Accidents')
plt.grid(True)
plt.show()
